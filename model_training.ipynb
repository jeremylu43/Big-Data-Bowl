# %%
import numpy as np
import pandas as pd
import nflreadpy as nfl
import seaborn as sns
import matplotlib.pyplot as plt
from xgboost import XGBClassifier

# %%
data = pd.read_csv('Data/Processed/processed_data.csv')

# %%
input_data = data.drop(['game_id', 'play_id', 'player_name', 'player_height', 'disruption', 'pd', 'int',
                        'pass_result', 'quarter', 'game_clock', 'down', 'yards_to_go'], axis = 1)

# %%
train = input_data[input_data['week'] <= 12].drop(['week'], axis = 1)
validate = input_data[(input_data['week'] <= 15) & (input_data['week'] > 12)].drop(['week'], axis = 1)
test = input_data[input_data['week'] > 15].drop(['week'], axis = 1)

# %%
X_train = train.drop(['outcome'], axis = 1)
y_train = train['outcome']
X_validate = validate.drop(['outcome'], axis = 1)
y_validate = validate['outcome']

# %%
bst = XGBClassifier(n_estimators=2, max_depth=2, learning_rate=1, objective='binary:logistic')
# fit model
bst.fit(X_train, y_train)
